# %% [markdown]
# <a href="https://colab.research.google.com/github/GibranLira/miweb1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Datos de probabilidad de lluvia y temperatura para ciudades
data_clima = {
    'Ciudad': ['New York', 'London', 'Tokyo', 'Sydney', 'Paris'],
    'Probabilidad de Lluvia (%)': [48, 60, 45, 54, 50],
    'Temperatura Promedio (°C)': [12.6, 11.3, 16.2, 21.1, 15.0],
    'Temperatura Maxima Promedio (°C)': [17.3, 15.0, 20.5, 25.0, 18.5],
    'Horas de Sol Promedio (h)': [2221, 1500, 1950, 2800, 1800]
}

df_clima = pd.DataFrame(data_clima)
df_clima
# Out:
#      Ciudad  Probabilidad de Lluvia (%)  Temperatura Promedio (°C)  \
# 0  New York                          48                       12.6
# 1    London                          60                       11.3
# 2     Tokyo                          45                       16.2
# 3    Sydney                          54                       21.1
# 4     Paris                          50                       15.0
#
#    Temperatura Maxima Promedio (°C)  Horas de Sol Promedio (h)
# 0                              17.3                       2221
# 1                              15.0                       1500
# 2                              20.5                       1950
# 3                              25.0                       2800
# 4                              18.5                       1800

# %%
# Datos estadísticos de la NBA (2024)
data_nba = {
    'Jugador': ['LeBron James', 'Giannis Antetokounmpo', 'Stephen Curry', 'Kevin Durant', 'Luka Doncic'],
    'Puntos por Partido': [28.9, 30.1, 33.4, 29.7, 32.5],
    'Asistencias por Partido': [7.6, 5.9, 6.4, 5.2, 8.1],
    'Rebotes por Partido': [8.1, 11.2, 5.3, 7.2, 8.6],
    'Robos por Partido': [1.2, 1.0, 1.3, 0.8, 1.0],
    'Bloqueos por Partido': [0.5, 1.4, 0.2, 1.7, 0.5]
}

df_nba = pd.DataFrame(data_nba)
df_nba
# Out:
#                  Jugador  Puntos por Partido  Asistencias por Partido  \
# 0           LeBron James                28.9                      7.6
# 1  Giannis Antetokounmpo                30.1                      5.9
# 2          Stephen Curry                33.4                      6.4
# 3           Kevin Durant                29.7                      5.2
# 4            Luka Doncic                32.5                      8.1
#
#    Rebotes por Partido  Robos por Partido  Bloqueos por Partido
# 0                  8.1                1.2                   0.5
# 1                 11.2                1.0                   1.4
# 2                  5.3                1.3                   0.2
# 3                  7.2                0.8                   1.7
# 4                  8.6                1.0                   0.5

# %%
# Datos demográficos y de salud globales
data_salud = {
    'País': ['China', 'India', 'USA', 'Indonesia', 'Brasil'],
    'Población (millones)': [1411, 1391, 331, 276, 213],
    'Esperanza de Vida (años)': [77.0, 70.5, 79.1, 71.6, 76.3],
    'Tasa de Mortalidad (por 1000 habitantes)': [7.1, 7.3, 8.2, 6.6, 6.2],
    'Tasa de Natalidad (por 1000 habitantes)': [10.4, 17.2, 12.0, 19.0, 14.2]
}

df_salud = pd.DataFrame(data_salud)
df_salud
# Out:
#         País  Población (millones)  Esperanza de Vida (años)  \
# 0      China                  1411                      77.0
# 1      India                  1391                      70.5
# 2        USA                   331                      79.1
# 3  Indonesia                   276                      71.6
# 4     Brasil                   213                      76.3
#
#    Tasa de Mortalidad (por 1000 habitantes)  \
# 0                                       7.1
# 1                                       7.3
# 2                                       8.2
# 3                                       6.6
# 4                                       6.2
#
#    Tasa de Natalidad (por 1000 habitantes)
# 0                                     10.4
# 1                                     17.2
# 2                                     12.0
# 3                                     19.0
# 4                                     14.2
